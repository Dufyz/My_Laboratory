# %%
import  matplotlib.pyplot as plt
import random

# %%
x = ['Dezembro','Janeiro', 'Fevereiro', 'Março', 'Abril']
y = [0,20,17,15,50]

# %%
plt.plot(x, y)

plt.title('Vendas - Roupas')

#plt.xlabel('MÊS')
plt.ylabel('QUANTIDADE')

plt.show()

# %%
a = [1,2]
b = [1,2]

plt.plot(a,b)

#plt.title('VENDAS JANEIRO')

#plt.xlabel = ('MÊS')
#plt.ylabel = ('QUANTIDADE VENDIDA')

plt.show()

# %%
w = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho']
z = [20, 50, 5,100,70,30]

# %%
plt.plot(w,z)

plt.title('1 Semestre 2021')

plt.xlabel('MÊS')
plt.ylabel('VENDAS')

plt.show()
