# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('G:\Meu Drive\My Laboratory\Jupyter Lab\databases\datasets\\Pokemon.csv')

# %%
# df.to_excel('G:\Meu Drive\Jupyter Lab\databases\datasets\\Poke.xlsx')
# df.to_csv('G:\Meu Drive\Jupyter Lab\databases\datasets\\Pokes.csv', sep = ';')

# %%
df['Total02'] = lista

# %%
df = df.drop(columns = 'Total2')

# %%
sum_column = df['HP'] + df['Attack']
df["HPATTACK"] = sum_column

# %%
df = df.drop(columns = ['SUM2'])

# %%
#df['SUM'] = df.iloc[:, 4:11].sum(axis = 1)
df['Total'] = df.loc[:, 'HP':'Speed'].sum(axis = 1)

# %%
df['Generation'].value_counts().sort_index()
# Out:
# 1    166
# 2    106
# 3    160
# 4    121
# 5    165
# 6     82
# Name: Generation, dtype: int64

# %%
df['Generation'].value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %%
df.head(15)
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison  45      49       49
# 1    2                    Ivysaur  Grass  Poison  60      62       63
# 2    3                   Venusaur  Grass  Poison  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison  80     100      123
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 9    7                   Squirtle  Water     NaN  44      48       65
# 10   8                  Wartortle  Water     NaN  59      63       80
# 11   9                  Blastoise  Water     NaN  79      83      100
# ...

# %%
filt = df.index == 6

# %%
df.loc[filt]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 6  6  Charizard   Fire  Flying  78      84       78      109       85    100
#
#    Generation  Legendary  Total
# 6           1      False    534

# %%
filt2 = df['#'] == 6

# %%
df.loc[filt2]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 6       85    100           1      False    534
# 7       85    100           1      False    634
# 8      115    100           1      False    634

# %%
#filt_type = df['Type 1'] == 'Fire' df['Type 2'] == 'Dragon'

# %%
filt_type1 = df['Type 1'] == 'Fire'
filt_type2 = df['Type 2'] == 'Flying'

# %%
df.loc[filt_type1 & filt_type2]
# Out:
#        #                       Name Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard   Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y   Fire  Flying   78     104       78
# 158  146                    Moltres   Fire  Flying   90     100       90
# 270  250                      Ho-oh   Fire  Flying  106     130       90
# 730  662                Fletchinder   Fire  Flying   62      73       55
# 731  663                 Talonflame   Fire  Flying   78      81       71
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 6        109       85    100           1      False    534
# 8        159      115    100           1      False    634
# 158      125       85     90           1       True    580
# 270      110      154     90           2       True    680
# 730       56       52     84           6      False    382
# 731       74       69    126           6      False    499

# %%
filt_type = (df['Type 1'] == 'Rock') & (df['Type 2'] == 'Dark')

# %%
df.loc[filt_type]
# Out:
#        #                     Name Type 1 Type 2   HP  Attack  Defense  \
# 267  248                Tyranitar   Rock   Dark  100     134      110
# 268  248  TyranitarMega Tyranitar   Rock   Dark  100     164      150
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 267       95      100     61           2      False    600
# 268       95      120     71           2      False    700

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Dragon       32
# Ghost        32
# Ground       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df.loc[df['Type 2'] == 'Dark']
# Out:
#        #                     Name    Type 1 Type 2   HP  Attack  Defense  \
# 141  130    GyaradosMega Gyarados     Water   Dark   95     155      109
# 267  248                Tyranitar      Rock   Dark  100     134      110
# 268  248  TyranitarMega Tyranitar      Rock   Dark  100     164      150
# 297  274                  Nuzleaf     Grass   Dark   70      70       40
# 298  275                  Shiftry     Grass   Dark   90     100       60
# 347  318                 Carvanha     Water   Dark   45      90       20
# 348  319                 Sharpedo     Water   Dark   70     120       40
# 349  319    SharpedoMega Sharpedo     Water   Dark   70     140       70
# 363  332                 Cacturne     Grass   Dark   70     115       60
# 374  342                Crawdaunt     Water   Dark   63     120       85
# 482  434                   Stunky    Poison   Dark   63      63       47
# 483  435                 Skuntank    Poison   Dark  103      93       67
# ...
