# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('G:\Meu Drive\Jupyter Lab\databases\datasets\\netflix_titles.csv')

# %%
df[['country', 'type']].value_counts()
# Out:
# country                  type
# United States            Movie      1850
# India                    Movie       852
# United States            TV Show     705
# United Kingdom           TV Show     204
#                          Movie       193
#                                     ...
# Spain, Portugal          Movie         1
# Spain, Mexico, France    Movie         1
# Spain, Italy, Argentina  Movie         1
# Spain, Italy             TV Show       1
# Norway, Germany, Sweden  TV Show       1
# Length: 773, dtype: int64

# %%
filt = df['country'] == 'Brazil'
df.loc[filt].head(5)
# Out:
#     show_id     type                      title                      director  \
# 0        s1  TV Show                         3%                           NaN
# 208    s209    Movie           A new Capitalism                           NaN
# 218    s219  TV Show            A Queen Is Born                  Carla Barros
# 320    s321    Movie  Afonso Padilha: Classless  Junior Carelli, Rudge Campos
# 322    s323  TV Show        Afronta! Facing It!               Juliana Vicente
#
#                                                   cast country  \
# 0    João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 208                                                NaN  Brazil
# 218                      Gloria Groove, Alexia Twister  Brazil
# 320                                     Afonso Padilha  Brazil
# 322  Loo Nascimento, Ingrid Silva, Rincon Sapiência...  Brazil
#
#             date_added  release_year rating   duration  \
# 0      August 14, 2020          2020  TV-MA  4 Seasons
# ...

# %%
filt_02 = df['date_added'] == 'November 1, 2019'

# %%
df.loc[filt_02].head(5)
# Out:
#      show_id   type               title                         director  \
# 266     s267  Movie  Aajcha Divas Majha             Chandrakant Kulkarni
# 274     s275  Movie           Aata Pita                    Uttung Shelar
# 435     s436  Movie             AlphaGo                        Greg Kohs
# 699     s700  Movie               Badha  Sumitra Bhave, Sunil Sukthankar
# 1188   s1189  Movie      Camp Cool Kids                      Lisa Arnold
#
#                                                    cast        country  \
# 266   Sachin Khedekar, Ashwini Bhave, Mahesh Manjrek...          India
# 274   Sanjay Narvekar, Bharat Jadhav, Satish Phuleka...          India
# 435                                                 NaN  United States
# 699   Amruta Subhash, Rajesh More, Devika Daftardar,...          India
# 1188  Connor Rosen, Logan Shroyer, Michael Gross, Ma...  United States
#
#            date_added  release_year rating duration  \
# ...

# %%
df['date_added'].value_counts()
# Out:
# January 1, 2020      118
# November 1, 2019      94
# March 1, 2018         76
# December 31, 2019     76
# October 1, 2018       72
#                     ...
# June 27, 2017          1
# June 26, 2015          1
# July 17, 2015          1
# January 19, 2017       1
# March 16, 2016         1
# Name: date_added, Length: 1565, dtype: int64

# %%
#filt = df['country'] == 'Brazil'
filt_02 = df['date_added'] == 'June 12, 2018'

# %%
df.filter(like = 'ty')
df.filter(like = 'a')
# Out:
#                                                    cast          date_added  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...     August 14, 2020
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...   December 23, 2016
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...   December 20, 2018
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...   November 16, 2017
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...     January 1, 2020
# ...                                                 ...                 ...
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...    October 19, 2020
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...       March 2, 2019
# 7784                                            Nasty C  September 25, 2020
# 7785                         Adriano Zumbo, Rachel Khoo    October 31, 2020
# 7786                                                NaN       March 1, 2020
#
#       release_year rating   duration
# ...

# %%
df.loc[filt & filt_02].head(3)
# Out:
#      show_id   type               title     director  \
# 435     s436  Movie             AlphaGo    Greg Kohs
# 1188   s1189  Movie      Camp Cool Kids  Lisa Arnold
# 2316   s2317  Movie  Functional Fitness     Bob Rose
#
#                                                    cast        country  \
# 435                                                 NaN  United States
# 1188  Connor Rosen, Logan Shroyer, Michael Gross, Ma...  United States
# 2316                                                NaN  United States
#
#            date_added  release_year rating duration  \
# 435   January 1, 2018          2017   TV-G   90 min
# 1188  January 1, 2018          2017   TV-G  104 min
# 2316  January 1, 2018          2016  TV-MA  106 min
#
#                                        listed_in  \
# 435                                Documentaries
# 1188  Children & Family Movies, Comedies, Dramas
# 2316                               Documentaries
#
# ...

# %%
filt = df['country'] == 'United States'
filt_02 = df['date_added'] == 'January 1, 2018'
filt_03 = df['release_year'] == 2017
filt_04 = df['rating'] == 'TV-G'

# %%
df.loc[filt & filt_02 & filt_03 & filt_04]['date_added'].value_counts()
# Out:
# January 1, 2018    2
# Name: date_added, dtype: int64

# %%
df['xesH'] = 'Olá'

# %%
df = df.drop(columns = 'xesH')

# %%
df.head(3)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 cast    country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          description xesH
# ...

# %%
df = df.drop(df.index[0:10])

# %%
#df = df.drop(df.index[df['show_id'] == 's10'])
df = df.drop([1,3,5])

# %%
df.head(5)
# Out:
#   show_id     type                title          director  \
# 0     s30  TV Show             #blackAF               NaN
# 1     s31    Movie     #cats_the_mewvie  Michael Margolis
# 2     s32    Movie    #FriendButMarried     Rako Prijanto
# 3     s33    Movie  #FriendButMarried 2     Rako Prijanto
# 4     s34    Movie         #realityhigh  Fernando Lebrija
#
#                                                 cast        country  \
# 0  Kenya Barris, Rashida Jones, Iman Benson, Genn...  United States
# 1                                                NaN         Canada
# 2  Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...      Indonesia
# 3  Adipati Dolken, Mawar de Jongh, Sari Nila, Von...      Indonesia
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...  United States
#
#           date_added  release_year rating  duration  \
# 0     April 17, 2020          2020  TV-MA  1 Season
# 1   February 5, 2020          2020  TV-14    90 min
# ...

# %%
df = pd.read_csv('G:\Meu Drive\Jupyter Lab\databases\datasets\\netflix_titles.csv')

# %%
#df = df.set_index('id', drop=True, append=False, inplace=False, verify_integrity=False)

# %%
df = df.reset_index()

# %%
df = df.drop(columns = ['level_0', 'index'])

# %%
df.head()
# Out:
#   show_id     type                title          director  \
# 0     s30  TV Show             #blackAF               NaN
# 1     s31    Movie     #cats_the_mewvie  Michael Margolis
# 2     s32    Movie    #FriendButMarried     Rako Prijanto
# 3     s33    Movie  #FriendButMarried 2     Rako Prijanto
# 4     s34    Movie         #realityhigh  Fernando Lebrija
#
#                                                 cast        country  \
# 0  Kenya Barris, Rashida Jones, Iman Benson, Genn...  United States
# 1                                                NaN         Canada
# 2  Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...      Indonesia
# 3  Adipati Dolken, Mawar de Jongh, Sari Nila, Von...      Indonesia
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...  United States
#
#           date_added  release_year rating  duration  \
# 0     April 17, 2020          2020  TV-MA  1 Season
# 1   February 5, 2020          2020  TV-14    90 min
# ...
